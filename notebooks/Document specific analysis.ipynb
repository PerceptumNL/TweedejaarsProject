# %%
import os, sys
import cPickle as pickle
from decimal import Decimal
sys.path.append(os.path.join(os.path.abspath('..'), 'src'))
from DocumentLinker import DocumentLinker
from datawrapper import DataWrapper
import operator
import pandas
import numpy as np
import scipy as sp

name_dict = pickle.load(open('../data/title_id_mapping.pickle'))

def getAverageDict(vectors, name_dict):
    vectors = [x[1].todense() for x in vectors]
    average = vectors[0]
    for i in vectors:
        average += i
    average = np.array(average/len(vectors))[0]
    average = dict((name_dict[i], average[i]) for i in range(0, len(average)))
    return average

def getVectors(new_doc, vectorList, data, vectorizer):
    vectorizer = getattr(__import__('vectorizers.' + vectorizer), vectorizer)
    data_bows, new_doc_bow, vec = vectorizer.vectorize(data, new_doc, True)
    name_dict = vec.get_feature_names()
    average = getAverageDict(data_bows, name_dict)
    
    vectors = [(-1, new_doc_bow)]
    
    vectorDicts = []
    for i in vectorList:
        for x in data_bows:
            if x[0] == i:
                vectors.append(x)
                break
    for vector in vectors:
        indices = vector[1].indices
        vectorDict = {}
        for j in range (0, len(indices)):
            vectorDict[name_dict[indices[j]]] = vector[1].data[j]
        vectorDict = sorted(vectorDict.iteritems(), key=operator.itemgetter(1))
        vectorDicts.append((vector[0], vectorDict))
    return average, vectorDicts

def getCosineDiff(vector1, vector2, average):
    dict1 = {}
    dict2 = {}
    dict3 = {}

    for i, j in vector1:
        dict1[i] = j
    for i, j in vector2:
        dict2[i] = j
        if dict1.has_key(i):
            dict3[i] = abs(dict1[i] - j) - average[i]

    vectorDict1 = sorted(dict1.iteritems(), key=operator.itemgetter(1))
    vectorDict2 = sorted(dict2.iteritems(), key=operator.itemgetter(1))
    vectorDict3 = sorted(dict3.iteritems(), key=operator.itemgetter(1))

    return [vectorDict1, vectorDict2, vectorDict3]

# Get differences all real links of a document
def proposedLinksTable(item_id, vectorizer = 'textvectorizer', distance='cosine', k = 10):
    data = DataWrapper('../data/expert_maybe_true.pickle')
    new_doc, data = data.remove_item(item_id)
    linker = DocumentLinker(data, k)
    linker.get_links(new_doc, vectorizer, distance)
    
    nlinks = []
    for link in linker.links:
        nlinks.append(link[0])
    average, proposed = getVectors(new_doc, nlinks, data, vectorizer)
    
    # Set the item itself in proper format in the list
    diff = [getCosineDiff(proposed[0][1], proposed[0][1], average)[1]]
    
    # Now find differences for all other items
    for i in proposed:
        if i[0] == -1:
            continue
        diff.append(getCosineDiff(proposed[0][1], i[1], average)[2])

    df = pandas.DataFrame(diff).transpose()
    df.columns = [0] + [data.value_for_keys(x, 'title', 'name') for x in nlinks]
    pandas.option_context('display.max_rows', 1000)
    return df
    

def trueLinksTable(item_id, vectorizer = 'textvectorizer', distance='cosine'):
    data = DataWrapper('../data/expert_maybe_true.pickle')
    new_doc, data = data.remove_item(item_id)
    linker = DocumentLinker(data, len(data.data['items']))
    linker.get_links(new_doc, vectorizer, distance)
    
    nlinks = []
    for link in linker.links:
        if link[0] in new_doc['links']:
            nlinks.append(link[0])
    average, proposed = getVectors(new_doc, nlinks, data, vectorizer)
    
    # Set the item itself in proper format in the list
    diff = [getCosineDiff(proposed[0][1], proposed[0][1], average)[1]]
    
    # Now find differences for all other items
    for i in proposed:
        if i[0] == -1:
            continue
        diff.append(getCosineDiff(proposed[0][1], i[1], average)[2])

    df = pandas.DataFrame(diff).transpose()
    df.columns = [0] + [data.value_for_keys(x, 'title', 'name') for x in nlinks]
    pandas.option_context('display.max_rows', 1000)
    return df

def table(item_id, k = 10):
    data = DataWrapper('../data/expert_maybe_true.pickle')
    new_doc, data = data.remove_item(11)
    linker = DocumentLinker(data, 10)
    linker.get_links(new_doc, 'textvectorizer', 'cosine')
    links = [x[0] for x in linker.links]
    links.append(5)
    average, proposed = getVectors(new_doc, links, data, vectorizer)

    df = pandas.DataFrame(map(lambda x: x[1], proposed)).transpose()
    df.columns = [0] + [data.value_for_keys(x, 'title', 'name') for x in links]
    pandas.option_context('display.max_rows', 231)
    df

# %%
proposedLinksTable(11)
# Out:
#                                   0                            BRAVO  \
# 0      (chemistry, 0.0274286189579)       (group, -0.00860937906102)
# 1       (research, 0.0302026894681)   (developed, -0.00555497542793)
# 2          (group, 0.0345395429511)     (download, -0.0053799725813)
# 3      (developed, 0.0352631788416)     (results, -0.00528339187893)
# 4            (uva, 0.0352631788416)       (learn, -0.00445726374189)
# 5        (working, 0.0352631788416)         (pdf, -0.00398848984642)
# 6       (download, 0.0356427015088)  (individual, -0.00229835563609)
# 7         (active, 0.0364412528992)         (end, -0.00130589665954)
# 8        (results, 0.0372990085328)  (motivation, -0.00110497124215)
# 9           (tool, 0.0372990085328)    (funding, -0.000690894997451)
# 10          (2013, 0.0377529649249)      (leader, -0.00023390125689)
# 11         (learn, 0.0377529649249)       (euro, -0.000160751533443)
# 12           (pdf, 0.0403357186111)     (budget, -0.000160751533443)
# 13       (develop, 0.0403357186111)        (000, -9.88281404526e-05)
# 14          (help, 0.0415552038195)     (personal, 0.00018920577346)
# 15      (specific, 0.0415552038195)        (andr, 0.000867701467543)
# 16      (material, 0.0436654672356)      (project, 0.00737784060799)
# 17           (2014, 0.044464018626)      (different, 0.018779971426)
# 18     (individual, 0.044464018626)        (course, 0.0214074374337)
# 19       (sciences, 0.044464018626)           (uva, 0.0258283095594)
# 20    (mathematics, 0.044464018626)        (online, 0.0263998170354)
# 21  (constructive, 0.0453217742596)       (improve, 0.0357917610016)
# 22    (motivation, 0.0453217742596)      (material, 0.0401421986188)
# 23           (end, 0.0453217742596)         (start, 0.0405490960267)
# 24       (systems, 0.0462482209218)      (students, 0.0581154391409)
# 25       (organic, 0.0462482209218)          (heck, 0.0602722158679)
# 26         (tasks, 0.0462482209218)    (biomedical, 0.0692659575929)
# 27       (digital, 0.0462482209218)       (student, 0.0719440848194)
# 28     (materials, 0.0462482209218)      (research, 0.0769479927146)
# 29        (better, 0.0472553257802)      (sciences, 0.0867674015157)
# 30   (environment, 0.0472553257802)        (digital, 0.091182770011)
# 31     (resources, 0.0472553257802)       (learning, 0.120301024496)
# 32      (selected, 0.0483584843379)    (mathematics, 0.220443192373)
# 33       (funding, 0.0495779695464)                             None
# 34       (various, 0.0495779695464)                             None
# 35      (bachelor, 0.0495779695464)                             None
# 36          (surf, 0.0495779695464)                             None
# 37      (expected, 0.0509412380241)                             None
# 38        (effect, 0.0509412380241)                             None
# 39        (follow, 0.0524867843528)                             None
# 40        (leader, 0.0524867843528)                             None
# 41         (gives, 0.0524867843528)                             None
# 42        (budget, 0.0524867843528)                             None
# 43          (euro, 0.0524867843528)                             None
# 44      (personal, 0.0542709866486)                             None
# 45         (april, 0.0542709866486)                             None
# 46           (000, 0.0542709866486)                             None
# 47   (opportunity, 0.0542709866486)                             None
# 48         (leads, 0.0563812500647)                             None
# 49      (overview, 0.0563812500647)                             None
# 50  (environments, 0.0563812500647)                             None
# 51        (sowiso, 0.0563812500647)                             None
# 52      (proposal, 0.0563812500647)                             None
# 53         (value, 0.0563812500647)                             None
# 54  (applications, 0.0563812500647)                             None
# 55       (insight, 0.0589640037509)                             None
# 56          (risk, 0.0589640037509)                             None
# 57          (heck, 0.0589640037509)                             None
# 58          (july, 0.0589640037509)                             None
# 59  (continuously, 0.0589640037509)                             None
# 60      (oriented, 0.0589640037509)                             None
# 61     (different, 0.0599280670022)                             None
# 62      (attitude, 0.0622937523755)                             None
# 63           (bio, 0.0622937523755)                             None
# 64     (intensity, 0.0622937523755)                             None
# 65       (measure, 0.0622937523755)                             None
# 66       (biology, 0.0622937523755)                             None
# 67       (academy, 0.0622937523755)                             None
# 68         (hints, 0.0622937523755)                             None
# 69          (andr, 0.0622937523755)                             None
# 70         (added, 0.0622937523755)                             None
# 71        (course, 0.0634964715938)                             None
# 72      (relation, 0.0669867694777)                             None
# 73    (biomedical, 0.0669867694777)                             None
# 74       (changes, 0.0669867694777)                             None
# 75     (addressed, 0.0669867694777)                             None
# 76            (18, 0.0669867694777)                             None
# 77   (comparative, 0.0669867694777)                             None
# 78     (questions, 0.0697914131408)                             None
# 79        (online, 0.0712854030176)                             None
# 80          (start, 0.088928037252)                             None
# 81         (change, 0.108541973297)                             None
# 82          (helps, 0.108541973297)                             None
# 83        (student, 0.118920796792)                             None
# 84        (improve, 0.124665611459)                             None
# 85        (success, 0.152823714072)                             None
# 86      (analytics, 0.162812959946)                             None
# 87             (use, 0.16688680899)                             None
# 88         (students, 0.1803791681)                             None
# 89          (study, 0.201678593055)                             None
# 90       (behavior, 0.235856015004)                             None
# 91       (learning, 0.252396066826)                             None
# 92        (project, 0.258503623074)                             None
# 93          (coach, 0.401920616866)                             None
# 94      (dashboard, 0.468907386344)                             None
#
#    Is there a project document / proposal available?  \
# 0                           (coach, 0.0998641011399)
# 1                          (project, 0.156670877807)
# 2                         (proposal, 0.195195108813)
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None
# 8                                               None
# 9                                               None
# 10                                              None
# 11                                              None
# 12                                              None
# 13                                              None
# 14                                              None
# 15                                              None
# 16                                              None
# 17                                              None
# 18                                              None
# 19                                              None
# 20                                              None
# 21                                              None
# 22                                              None
# 23                                              None
# 24                                              None
# 25                                              None
# 26                                              None
# 27                                              None
# 28                                              None
# 29                                              None
# 30                                              None
# 31                                              None
# 32                                              None
# 33                                              None
# 34                                              None
# 35                                              None
# 36                                              None
# 37                                              None
# 38                                              None
# 39                                              None
# 40                                              None
# 41                                              None
# 42                                              None
# 43                                              None
# 44                                              None
# 45                                              None
# 46                                              None
# 47                                              None
# 48                                              None
# 49                                              None
# 50                                              None
# 51                                              None
# 52                                              None
# 53                                              None
# 54                                              None
# 55                                              None
# 56                                              None
# 57                                              None
# 58                                              None
# 59                                              None
# 60                                              None
# 61                                              None
# 62                                              None
# 63                                              None
# 64                                              None
# 65                                              None
# 66                                              None
# 67                                              None
# 68                                              None
# 69                                              None
# 70                                              None
# 71                                              None
# 72                                              None
# 73                                              None
# 74                                              None
# 75                                              None
# 76                                              None
# 77                                              None
# 78                                              None
# 79                                              None
# 80                                              None
# 81                                              None
# 82                                              None
# 83                                              None
# 84                                              None
# 85                                              None
# 86                                              None
# 87                                              None
# 88                                              None
# 89                                              None
# 90                                              None
# 91                                              None
# 92                                              None
# 93                                              None
# 94                                              None
#
#                   Learning Analytics                Learning Analytics  \
# 0       (research, -0.0129368112497)      (research, -0.0129368112497)
# 1          (april, 0.00469557841949)         (april, 0.00469557841949)
# 2          (value, 0.00496678169849)         (value, 0.00496678169849)
# 3   (environments, 0.00516418424563)  (environments, 0.00516418424563)
# 4       (oriented, 0.00569976693932)      (oriented, 0.00569976693932)
# 5        (learning, 0.0199869628775)       (learning, 0.0199869628775)
# 6       (different, 0.0226865009461)      (different, 0.0226865009461)
# 7       (questions, 0.0238981299852)      (questions, 0.0238981299852)
# 8         (digital, 0.0318910109915)        (digital, 0.0318910109915)
# 9         (improve, 0.0466271934495)        (improve, 0.0466271934495)
# 10        (students, 0.122458129825)        (students, 0.122458129825)
# 11           (study, 0.160603829903)           (study, 0.160603829903)
# 12       (analytics, 0.409337696279)       (analytics, 0.409337696279)
# 13                              None                              None
# 14                              None                              None
# 15                              None                              None
# 16                              None                              None
# 17                              None                              None
# 18                              None                              None
# 19                              None                              None
# 20                              None                              None
# 21                              None                              None
# 22                              None                              None
# 23                              None                              None
# 24                              None                              None
# 25                              None                              None
# 26                              None                              None
# 27                              None                              None
# 28                              None                              None
# 29                              None                              None
# 30                              None                              None
# 31                              None                              None
# 32                              None                              None
# 33                              None                              None
# 34                              None                              None
# 35                              None                              None
# 36                              None                              None
# 37                              None                              None
# 38                              None                              None
# 39                              None                              None
# 40                              None                              None
# 41                              None                              None
# 42                              None                              None
# 43                              None                              None
# 44                              None                              None
# 45                              None                              None
# 46                              None                              None
# 47                              None                              None
# 48                              None                              None
# 49                              None                              None
# 50                              None                              None
# 51                              None                              None
# 52                              None                              None
# 53                              None                              None
# 54                              None                              None
# 55                              None                              None
# 56                              None                              None
# 57                              None                              None
# 58                              None                              None
# 59                              None                              None
# 60                              None                              None
# 61                              None                              None
# 62                              None                              None
# 63                              None                              None
# 64                              None                              None
# 65                              None                              None
# 66                              None                              None
# 67                              None                              None
# 68                              None                              None
# 69                              None                              None
# 70                              None                              None
# 71                              None                              None
# 72                              None                              None
# 73                              None                              None
# 74                              None                              None
# 75                              None                              None
# 76                              None                              None
# 77                              None                              None
# 78                              None                              None
# 79                              None                              None
# 80                              None                              None
# 81                              None                              None
# 82                              None                              None
# 83                              None                              None
# 84                              None                              None
# 85                              None                              None
# 86                              None                              None
# 87                              None                              None
# 88                              None                              None
# 89                              None                              None
# 90                              None                              None
# 91                              None                              None
# 92                              None                              None
# 93                              None                              None
# 94                              None                              None
#
#    STEEP: Supporting Technology Enhanced Education Projects  \
# 0                      (developed, -0.00304632590255)
# 1                       (download, -0.00284432352298)
# 2                            (pdf, -0.00111897596046)
# 3                            (2014, 0.00162722756854)
# 4                             (end, 0.00191832904047)
# 5                      (motivation, 0.00211925445787)
# 6                         (funding, 0.00283611969201)
# 7                          (leader, 0.00350004874366)
# 8                          (budget, 0.00357319846711)
# 9                            (euro, 0.00357319846711)
# 10                             (uva, 0.0178086489372)
# 11                             (2013, 0.023623698645)
# 12                         (results, 0.0243268851947)
# 13                          (course, 0.0420939776658)
# 14                           (start, 0.0456051679833)
# 15                        (specific, 0.0685009421639)
# 16                         (project, 0.0732925124762)
# 17                           (online, 0.078937625325)
# 18                        (learning, 0.0916897945591)
# 19                              (use, 0.100775361921)
# 20                         (students, 0.101619008776)
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
# 59                                               None
# 60                                               None
# 61                                               None
# 62                                               None
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
# 73                                               None
# 74                                               None
# 75                                               None
# 76                                               None
# 77                                               None
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
# 83                                               None
# 84                                               None
# 85                                               None
# 86                                               None
# 87                                               None
# 88                                               None
# 89                                               None
# 90                                               None
# 91                                               None
# 92                                               None
# 93                                               None
# 94                                               None
#
#                        SmartVoting                 Group projects  \
# 0       (2013, -7.70338416237e-05)  (students, -0.00499689942544)
# 1    (download, 0.000539483300052)      (learn, 0.00639478816973)
# 2          (pdf, 0.00271037125708)  (different, 0.00795558880068)
# 3          (end, 0.00622103681738)    (develop, 0.00858195747005)
# 4   (motivation, 0.00642196223477)  (questions, 0.00931790288551)
# 5      (funding, 0.00754289736378)    (expected, 0.0143854354929)
# 6       (budget, 0.00855612993677)     (student, 0.0633981688713)
# 7         (euro, 0.00855612993677)     (improve, 0.0662864817287)
# 8          (000, 0.00891436944292)      (project, 0.101977472844)
# 9      (oriented, 0.0103151426681)      (results, 0.103067160622)
# 10       (online, 0.0174456864358)        (group, 0.182131327774)
# 11        (start, 0.0331646165843)     (research, 0.309311414879)
# 12        (group, 0.0381378432283)                           None
# 13       (results, 0.045198603367)                           None
# 14      (student, 0.0670065633902)                           None
# 15      (improve, 0.0713300930645)                           None
# 16          (use, 0.0852109873305)                           None
# 17       (project, 0.105047877029)                           None
# 18    (individual, 0.110675987592)                           None
# 19      (students, 0.115773918258)                           None
# 20       (learning, 0.18125001616)                           None
# 21                            None                           None
# 22                            None                           None
# 23                            None                           None
# 24                            None                           None
# 25                            None                           None
# 26                            None                           None
# 27                            None                           None
# 28                            None                           None
# 29                            None                           None
# 30                            None                           None
# 31                            None                           None
# 32                            None                           None
# 33                            None                           None
# 34                            None                           None
# 35                            None                           None
# 36                            None                           None
# 37                            None                           None
# 38                            None                           None
# 39                            None                           None
# 40                            None                           None
# 41                            None                           None
# 42                            None                           None
# 43                            None                           None
# 44                            None                           None
# 45                            None                           None
# 46                            None                           None
# 47                            None                           None
# 48                            None                           None
# 49                            None                           None
# 50                            None                           None
# 51                            None                           None
# 52                            None                           None
# 53                            None                           None
# 54                            None                           None
# 55                            None                           None
# 56                            None                           None
# 57                            None                           None
# 58                            None                           None
# 59                            None                           None
# 60                            None                           None
# 61                            None                           None
# 62                            None                           None
# 63                            None                           None
# 64                            None                           None
# 65                            None                           None
# 66                            None                           None
# 67                            None                           None
# 68                            None                           None
# 69                            None                           None
# 70                            None                           None
# 71                            None                           None
# 72                            None                           None
# 73                            None                           None
# 74                            None                           None
# 75                            None                           None
# 76                            None                           None
# 77                            None                           None
# 78                            None                           None
# 79                            None                           None
# 80                            None                           None
# 81                            None                           None
# 82                            None                           None
# 83                            None                           None
# 84                            None                           None
# 85                            None                           None
# 86                            None                           None
# 87                            None                           None
# 88                            None                           None
# 89                            None                           None
# 90                            None                           None
# 91                            None                           None
# 92                            None                           None
# 93                            None                           None
# 94                            None                           None
#
#                    Group projects Knowledge clips for active learning  \
# 0   (students, -0.00499689942544)        (students, -0.0030668718843)
# 1       (learn, 0.00639478816973)            (pdf, -0.00172433610898)
# 2   (different, 0.00795558880068)       (specific, 0.000130022585725)
# 3     (develop, 0.00858195747005)      (materials, 0.000994214678489)
# 4   (questions, 0.00931790288551)          (better, 0.00101718104359)
# 5     (expected, 0.0143854354929)      (motivation, 0.00143906337805)
# 6      (student, 0.0633981688713)         (funding, 0.00209205145567)
# 7      (improve, 0.0662864817287)           (leader, 0.0027123248933)
# 8       (project, 0.101977472844)          (budget, 0.00278547461674)
# 9       (results, 0.103067160622)            (euro, 0.00278547461674)
# 10        (group, 0.182131327774)             (000, 0.00294755014376)
# 11     (research, 0.309311414879)            (april, 0.0029767914557)
# 12                           None            (course, 0.014709545672)
# 13                           None             (2013, 0.0247568947918)
# 14                           None          (results, 0.0254464553485)
# 15                           None           (project, 0.029703650643)
# 16                           None             (2014, 0.0350969674927)
# 17                           None         (learning, 0.0509864691457)
# 18                           None           (active, 0.0916552540146)
# 19                           None              (use, 0.0999404805224)
# 20                           None                                None
# 21                           None                                None
# 22                           None                                None
# 23                           None                                None
# 24                           None                                None
# 25                           None                                None
# 26                           None                                None
# 27                           None                                None
# 28                           None                                None
# 29                           None                                None
# 30                           None                                None
# 31                           None                                None
# 32                           None                                None
# 33                           None                                None
# 34                           None                                None
# 35                           None                                None
# 36                           None                                None
# 37                           None                                None
# 38                           None                                None
# 39                           None                                None
# 40                           None                                None
# 41                           None                                None
# 42                           None                                None
# 43                           None                                None
# 44                           None                                None
# 45                           None                                None
# 46                           None                                None
# 47                           None                                None
# 48                           None                                None
# 49                           None                                None
# 50                           None                                None
# 51                           None                                None
# 52                           None                                None
# 53                           None                                None
# 54                           None                                None
# 55                           None                                None
# 56                           None                                None
# 57                           None                                None
# 58                           None                                None
# 59                           None                                None
# 60                           None                                None
# 61                           None                                None
# 62                           None                                None
# 63                           None                                None
# 64                           None                                None
# 65                           None                                None
# 66                           None                                None
# 67                           None                                None
# 68                           None                                None
# 69                           None                                None
# 70                           None                                None
# 71                           None                                None
# 72                           None                                None
# 73                           None                                None
# 74                           None                                None
# 75                           None                                None
# 76                           None                                None
# 77                           None                                None
# 78                           None                                None
# 79                           None                                None
# 80                           None                                None
# 81                           None                                None
# 82                           None                                None
# 83                           None                                None
# 84                           None                                None
# 85                           None                                None
# 86                           None                                None
# 87                           None                                None
# 88                           None                                None
# 89                           None                                None
# 90                           None                                None
# 91                           None                                None
# 92                           None                                None
# 93                           None                                None
# 94                           None                                None
#
#                   Online Schakelen
# 0    (students, -0.00925928857269)
# 1        (2013, -0.00117006459686)
# 2     (sciences, 0.00204364564628)
# 3           (uva, 0.0039025043372)
# 4    (materials, 0.00473998467677)
# 5     (bachelor, 0.00576749008498)
# 6     (developed, 0.0085329885843)
# 7     (download, 0.00885961422425)
# 8      (results, 0.00961790480401)
# 9         (learn, 0.0106253926915)
# 10          (pdf, 0.0121260004198)
# 11         (2014, 0.0162278073215)
# 12  (environment, 0.0166282520894)
# 13          (end, 0.0168005686597)
# 14   (motivation, 0.0170014940771)
# 15      (funding, 0.0191159594528)
# 16       (leader, 0.0207350514402)
# 17         (euro, 0.0208082011637)
# 18       (budget, 0.0208082011637)
# 19      (changes, 0.0280253299591)
# 20        (start, 0.0344519469955)
# 21       (course, 0.0354426963405)
# 22      (project, 0.0512246910351)
# 23      (student, 0.0678673175626)
# 24       (online, 0.0823512746599)
# 25           (use, 0.135152438926)
# 26      (learning, 0.145311674893)
# 27         (study, 0.149814048796)
# 28                            None
# 29                            None
# 30                            None
# 31                            None
# 32                            None
# 33                            None
# 34                            None
# 35                            None
# 36                            None
# 37                            None
# 38                            None
# 39                            None
# 40                            None
# 41                            None
# 42                            None
# 43                            None
# 44                            None
# 45                            None
# 46                            None
# 47                            None
# 48                            None
# 49                            None
# 50                            None
# 51                            None
# 52                            None
# 53                            None
# 54                            None
# 55                            None
# 56                            None
# 57                            None
# 58                            None
# 59                            None
# 60                            None
# 61                            None
# 62                            None
# 63                            None
# 64                            None
# 65                            None
# 66                            None
# 67                            None
# 68                            None
# 69                            None
# 70                            None
# 71                            None
# 72                            None
# 73                            None
# 74                            None
# 75                            None
# 76                            None
# 77                            None
# 78                            None
# 79                            None
# 80                            None
# 81                            None
# 82                            None
# 83                            None
# 84                            None
# 85                            None
# 86                            None
# 87                            None
# 88                            None
# 89                            None
# 90                            None
# 91                            None
# 92                            None
# 93                            None
# 94                            None
